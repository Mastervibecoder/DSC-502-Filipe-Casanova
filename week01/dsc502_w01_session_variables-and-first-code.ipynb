# %% [markdown]
# # DSC502: Coding — Week 1 Session Notebook
# ## QuickBite Food Delivery Platform
# ### Regent's University London
#
# ---
#
# ## Before you start
#
# Welcome to your first piece of code on this module.
#
# The goal today is simple: write a few things, run them, see what happens. You are not expected to produce a complete programme. You are expected to feel what it is like to write code yourself, hit an error, read the error message, and figure out what Python is telling you.
#
# That friction is deliberate. AI will make a lot of things easier from Week 5 onwards — but only if you have already experienced what the hard version feels like. So this week, you write everything yourself.
#
# **AI assistance rule for this notebook:** No AI generation. If you are completely stuck and genuinely cannot proceed, you may ask AI to *explain an error message or a concept* — but not to write or fix your code.
#
# **How to run a cell:** click on it, then press **Shift+Enter**.
#
# **If you want to understand *why* Python works the way it does** — what a programming language actually is, how Python reads your code, why data types exist — read the Week 1 section of the Course Companion before or after this session. This notebook is for doing; the companion is for understanding.
#
# ---
#
# ## The four questions — a seed to plant
#
# Everything we build on this module sits against four questions:
#
# 1. **Who is the user?**
# 2. **What problem does it solve?**
# 3. **Would someone pay for it?**
# 4. **How do you get it in front of them?**
#
# You do not need to answer these today. Keep them in the back of your mind — we will return to them properly in Week 5.
#
# ---

# %% [markdown]
# ## Part 0 — Hello, World!
#
# Every programmer writes this first. It is a tradition.
#
# It also does something useful: it confirms that your environment is working. If this cell runs and you see `Hello, World!` in the output, Python is talking to you.
#
# Run the cell below.

# %%
print("Hello, Milan")
# Out:
# Hello, Milan

# %% [markdown]
# Good. Now make it yours. Change the text inside the quote marks to anything you like and run it again.

# %%
# Change this to something of your own
print("Hello, Porto!")
# Out:
# Hello, Porto!

# %%
print ("hello" \
"")
# Out:
# hello

# %% [markdown]
# ---
#
# ## Part 1 — Variables
#
# A **variable** is a named container for a value. You create one like this:
#
# ```python
# platform_name = "QuickBite"
# ```
#
# The `=` sign means *store this value in this container*. After that line, every time you write `platform_name`, Python knows what you mean.
#
# Run the cell below and see what happens.

# %%
# Worked example — one variable, printed
platform_name = "QuickBite"
print(platform_name)
# Out:
# QuickBite

# %% [markdown]
# ### Quick exercise — your own variable
#
# Create a variable called `my_name` and store your first name in it. Print it.

# %%
# Your code here
platform_name = "contesta.AI"
print(platform_name)
# Out:
# contesta.AI

# %% [markdown]
# Now try creating two variables — your name and your favourite city — and print both.

# %%
# Two variables
My_name = "Filipe"
My_city = "Porto"
print (My_name , My_city)
print ( My_name , "is from" , My_city)
# Out:
# Filipe Porto
# Filipe is from Porto

# %% [markdown]
# ---
#
# ## Part 2 — Data types
#
# Python needs to know what *kind* of value a variable holds — its **data type**. The four most important right now:
#
# | Type | What it holds | Example |
# |------|---------------|---------|
# | `str` | Text (always in quote marks) | `"QuickBite"` |
# | `int` | Whole numbers (no quote marks) | `30` |
# | `float` | Decimal numbers | `4.7` |
# | `bool` | True or False only | `True` |
#
# The `type()` function tells you which type a variable is. Run the example below.

# %%
# Worked example — type() on one variable
platform_name = "QuickBite"
print(platform_name)
print(type(platform_name))
# Out:
# QuickBite
# <class 'str'>

# %% [markdown]
# ### Quick exercise — one of each type
#
# Below are four variables, one of each type. Run the cell as-is to see what `type()` returns for each.

# %%
# One variable of each type — run and observe
restaurant_name = "Burger Palace"   # str
delivery_time = 30                  # int
average_rating = 4.7                # float
is_open = True                      # bool

print(type(restaurant_name))
print(type(delivery_time))
print(type(average_rating))
print(type(is_open))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ### Exercise 1 — A QuickBite restaurant
#
# Now write it yourself. Create four variables describing a fictional restaurant on QuickBite:
# - `restaurant_name` — name of the restaurant (string)
# - `delivery_time_mins` — delivery time in minutes (integer)
# - `average_rating` — rating out of 5 (float)
# - `is_open` — whether it is currently accepting orders (bool)
#
# Make up realistic values. Then print each variable and its type.

# %%
# Exercise 1 — your code here
restaurant_name = "pizzahouse"
delivery_time = 30
average_rating = 5
is_open = True
print (type(restaurant_name))
print (type(delivery_time))
print (type(average_rating))
print (type(is_open))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>

# %% [markdown]
# ### Stretch — what happens when types collide?
#
# Try adding `restaurant_name` (a string) to `delivery_time_mins` (an integer). Uncomment the lines below, run the cell, and read the error carefully.

# %%
# Uncomment and run
# result = restaurant_name + delivery_time_mins
# print(result)
order_value = 12.99
quantity = 20
total_order_value = order_value * quantity
print (total_order_value)
# Out:
# 259.8

# %% [markdown]
# ### Commentary cell 1
#
# *Double-click this cell to edit it. Write 3–5 sentences.*
#
# What is a variable? What is a data type? Why does Python need to know which type it is dealing with? If you tried the stretch task, what did the error message say — and what is Python complaining about?

# %% [markdown]
# *(your answer here)*

# %% [markdown]
# ---
#
# ## Part 3 — f-strings
#
# Sooner or later you want to put a variable's value *inside* a sentence. You could try joining things with `+`:
#
# ```python
# print("Delivery time: " + delivery_time_mins + " minutes")
# ```
#
# But that fails if `delivery_time_mins` is a number. An **f-string** solves this cleanly. Write `f` before the opening quote, then put variable names in curly braces `{}`:
#
# ```python
# print(f"Delivery time: {delivery_time_mins} minutes")
# ```
#
# Python replaces `{delivery_time_mins}` with the actual value. Run the example below.

# %%
# Worked example — one variable in an f-string
platform_name = "QuickBite"
print(f"Welcome to {platform_name}!")
# Out:
# Welcome to QuickBite!

# %% [markdown]
# ### Quick exercise — one variable
#
# Write an f-string using `my_name` from Part 1. Something like: `"My name is [your name] and I'm learning Python."`

# %%
# Quick exercise — f-string with one variable
my_name = "Filipe"  # put your name here
print (f"my name is {my_name} and Im learning python")
# Out:
# my name is Filipe and Im learning python

# %% [markdown]
# Now try two variables in one f-string.

# %%
# Worked example — two variables in one f-string
restaurant_name = "Burger Palace"
average_rating = 4.7
print(f"{restaurant_name} has an average rating of {average_rating} out of 5.")
# Out:
# Burger Palace has an average rating of 4.7 out of 5.

# %% [markdown]
# ### Exercise 2 — Describe your restaurant
#
# Using the variables you created in Exercise 1, write two f-strings:
#
# 1. A sentence describing the restaurant — include the name, rating, and delivery time
# 2. A status sentence — write it *twice* manually: once saying the restaurant is open, once saying it is closed. Don't use an if statement — just write both versions by hand and print them both.

# %%
# Exercise 2 — your code here
restaurant_name = "Burger Palace"
average_rating = 4.7
delivery_time = 10
is_open = False
print (f"{restaurant_name} is rated at {average_rating} and takes usually {delivery_time} minutes")
print (f"{restaurant_name} is {is_open} ")
print (f"{restaurant_name} is closed ")
# Out:
# Burger Palace is rated at 4.7 and takes usually 10 minutes
# Burger Palace is False
# Burger Palace is closed

# %% [markdown]
# ### Commentary cell 2
#
# *Double-click this cell to edit it. Write 3–5 sentences.*
#
# What is an f-string and what problem does it solve? What would have happened if you had tried to build your sentence using `+` instead? Where did you get stuck in this exercise, and what did you do about it?

# %% [markdown]
# *(your answer here)*

# %% [markdown]
# ---
#
# ## Part 4 — Lists
#
# A **list** is an ordered collection of values stored in a single variable. You write it with square brackets, values separated by commas:
#
# ```python
# restaurants = ["Burger Palace", "Pizza Roma", "Sushi Garden"]
# ```
#
# Run the example and see what prints.

# %%
# Worked example — create a list and print it
restaurants = ["Burger Palace", "Pizza Roma", "Sushi Garden", "Taco Town"]
print(restaurants)
# Out:
# ['Burger Palace', 'Pizza Roma', 'Sushi Garden', 'Taco Town']

# %% [markdown]
# ### Quick exercise — your own list
#
# Create a list called `my_favourite_foods` with three items. Print it.

# %%
# Quick exercise
my_favourite_foods = ["pizza", "sushi", "picanha", "cataplana"]
print (my_favourite_foods)
# Out:
# ['pizza', 'sushi', 'picanha', 'cataplana']

# %% [markdown]
# ### Indexing — getting one item out
#
# Python counts from **zero**. The first item in a list is at index `[0]`.
#
# Negative indices count from the end: `[-1]` is always the last item.

# %%
# Worked example — indexing
restaurants = ["Burger Palace", "Pizza Roma", "Sushi Garden", "Taco Town"]

print(restaurants[0])    # First item
print(restaurants[1])    # Second item
print(restaurants[-1])   # Last item
# Out:
# Burger Palace
# Pizza Roma
# Taco Town

# %% [markdown]
# ### Quick exercise — indexing your list
#
# Using `my_favourite_foods` from above, print the first item, the last item, and use an f-string to print a sentence containing the first item.

# %%
# Quick exercise
print(my_favourite_foods [-1])
print(my_favourite_foods [0])
print(f"i love {my_favourite_foods [0]}")
# Out:
# cataplana
# pizza
# i love pizza

# %% [markdown]
# ### `len()`, `.append()`, and slicing

# %%
# Worked example — len, append, slice
restaurants = ["Burger Palace", "Pizza Roma", "Sushi Garden", "Taco Town"]

print(len(restaurants))          # How many items?

restaurants.append("The Noodle Bar")  # Add a new item
print(restaurants)               # See the updated list

print(restaurants[0:3])          # First three items (0, 1, 2 — not 3)
# Out:
# 4
# ['Burger Palace', 'Pizza Roma', 'Sushi Garden', 'Taco Town', 'The Noodle Bar']
# ['Burger Palace', 'Pizza Roma', 'Sushi Garden']

# %% [markdown]
# ### Exercise 3 — QuickBite menu items
#
# 1. Create a list called `menu_items` with at least **six** food items from your fictional QuickBite restaurant
# 2. Print the first item
# 3. Print the last item (use negative indexing)
# 4. Print the number of items using `len()`
# 5. Add a new item using `.append()` and print the updated list
# 6. Print the first three items using slicing

# %%
# Exercise 3 — your code here
menu_items = ["steak" , "pasta", "wine", "ice tea", "fish","lava cake"]
print(menu_items[0])
print (menu_items[-1])
print (len(menu_items))
menu_items.append("bread")
print(menu_items[0:3])
print (menu_items[-1])
# Out:
# steak
# lava cake
# 6
# ['steak', 'pasta', 'wine']
# bread

# %% [markdown]
# ### Stretch 1 — the `in` operator
#
# Check whether a specific item is in `menu_items` using `in`. Print a sentence using an f-string with the result.
#
# Example: `"chips" in menu_items` returns `True` or `False`.

# %%
# Stretch 1

# %% [markdown]
# ### Stretch 2 — sorting
#
# Try `.sort()` on your `menu_items` list. What does it do to the order? Now try it on a list of numbers. Do both work the same way?

# %%
# Stretch 2

# %% [markdown]
# ### Commentary cell 3
#
# *Double-click this cell to edit it. Write 3–5 sentences.*
#
# Why does Python count from 0 instead of 1? What does slicing give you — and why does `[0:3]` give items at index 0, 1, and 2 but *not* 3? What would a real food delivery platform use a list like `menu_items` for behind the scenes?

# %% [markdown]
# *(your answer here)*

# %% [markdown]
# ---
#
# ## Part 5 — Deliberate errors
#
# Error messages are not failures — they are information. Python is telling you exactly what went wrong and roughly where. Learning to read them is one of the most useful habits you will build on this module.
#
# Each cell below contains a bug. **Do not fix the bug before you run it.** Run it, read the error message, then fix the bug and run it again.
#
# Three common error types:
# - **TypeError** — you used the wrong data type for an operation
# - **IndexError** — you asked for a list position that does not exist
# - **NameError** — Python cannot find a variable with that name

# %%
# Bug 1 — run first, read the error, then fix it
delivery_time = 32
message = "Estimated delivery: " + delivery_time + " minutes"
print(message)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 # Bug 1 — run first, read the error, then fix it
#       2 delivery_time = 32
# ----> 3 message = "Estimated delivery: " + delivery_time + " minutes"
#       4 print(message)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Bug 2 — run first, read the error, then fix it
popular_items = ["Burger", "Fries", "Milkshake"]
print(popular_items[5])

# %%
# Bug 3 — run first, read the error, then fix it
Restaurant_Name = "Burger Palace"
print(restaurant_name)

# %% [markdown]
# ### Commentary cell 4
#
# *Double-click this cell to edit it. Write 3–5 sentences.*
#
# What are TypeError, IndexError, and NameError? What did each error message tell you about what went wrong? What habit could you build while coding that would help you avoid each of these?

# %% [markdown]
# *(your answer here)*

# %% [markdown]
# ---
#
# ## Part 6 — A glimpse of what's coming (optional, if time)
#
# No coding exercise here — just a peek. From Week 3 we will be working with real QuickBite data. Run the cell below and look at what comes out.

# %%
# A preview — what QuickBite data looks like
customer_names = ["Amara Osei", "Jin Park", "Sofia Martins", "Tom Hadley", "Priya Nair"]
order_totals   = [18.50, 32.00, 11.75, 24.90, 8.40]
delivery_times = [24, 38, 19, 41, 22]

print("Customers:", customer_names)
print("Order totals (£):", order_totals)
print("Delivery times (mins):", delivery_times)

print(f"\nFirst customer: {customer_names[0]}")
print(f"Their order total: £{order_totals[0]}")
print(f"Their delivery time: {delivery_times[0]} minutes")

# %% [markdown]
# ### Commentary cell 5 (optional)
#
# *Double-click this cell to edit it.*
#
# Looking at this data, what kinds of questions could a food delivery company want to ask of it? Think loosely about the four questions from the start of this notebook — who uses this data, and why does it matter to them?

# %% [markdown]
# *(your answer here — optional)*

# %% [markdown]
# ---
#
# ## You're done
#
# Well done — that was your first real Python.
#
# Push your work to GitHub before you close Codespaces:
#
# ```bash
# git add . && git commit -m "week 1 session" && git push
# ```
#
# Your homework notebook (`week1_homework.ipynb`) is in the same folder. Complete it before Week 2 — the scenario changes to RideAlong, but the Python is the same scope as today.
#
# **Reminder:** your repo URL should already be posted in your Blackboard Journal as your Week 1 anchor entry. If not, do that now.
